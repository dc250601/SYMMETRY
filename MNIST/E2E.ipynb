# %%
import numpy as np
import pickle
import os
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from tqdm.auto import tqdm
from torch.utils.data import TensorDataset, DataLoader
from torch.distributions.normal import Normal
import torch.nn.functional as F
import gc
import imutils
import math

import h5py
import data
import models
from models import *

# %%
DATAPATH = "/global/cfs/cdirs/m4392/www/ACAT_Backup/Data/QG/Quark_Gluon.h5"

# %%
# Taking a look at the mass and pT distribution for the dataset
data = h5py.File(DATAPATH,"r")
#Index 0 is Invariant Mass and Index 2 is PT

# %%
data
# Out:
# <HDF5 file "Quark_Gluon.h5" (mode r)>

# %%
data.keys()
# Out:
# <KeysViewHDF5 ['test_jet', 'test_meta', 'train_jet', 'train_meta', 'validation_jet', 'validation_meta']>

# %%
data["validation_meta"]
# Out:
# <HDF5 dataset "validation_meta": shape (83812, 3), type "<f4">

# %%
data["validation_meta"][0,:]
# Out:
# array([112.411095,  21.098248,   0.      ], dtype=float32)

# %%
plt.hist(data["validation_meta"][:10000,0],bins = 100)
plt.show()

# %%
plt.hist(data["validation_meta"][:10000,1],bins = 100)
plt.show()
